# %% [markdown]
# ### <center> Numerical Simulation and Scientific Computing I </center>

# %% [markdown]
# ### Team 11
# - Shakira Pannier (12509817)
# - Leon Orou (12125027)
# - Natalia Ksiazek (12507337)

# %% [markdown]
# ---
#
# ## Part 1

# %% [markdown]
# ### Phase plots
#
# steps = {100, 150, 200}

# %% [markdown]
# ![PhasePlot100](../ASC-ODE/demos/plots/MassSpringPhasePlot_100.png)
# ![PhasePlot150](../ASC-ODE/demos/plots/MassSpringPhasePlot_150.png)
# ![PhasePlot200](../ASC-ODE/demos/plots/MassSpringPhasePlot_200.png)

# %% [markdown]
# ### Time Evolution

# %% [markdown]
# steps = {100, 150, 200}

# %% [markdown]
# ![TimeEvolution100](../ASC-ODE/demos/plots/MassSpringSystemTimeEvolution_100.png)
# ![TimeEvolution150](../ASC-ODE/demos/plots/MassSpringSystemTimeEvolution_150.png)
# ![TimeEvolution200](../ASC-ODE/demos/plots/MassSpringSystemTimeEvolution_200.png)

# %% [markdown]
# ###
